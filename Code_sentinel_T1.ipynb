# %% [markdown]
# # **CODE SENTINEL Internship**

# %% [markdown]
# ## **Task 1:**
# Download a dataset (e.g., Iris, Titanic, or your own .csv).
# Write a script that:
# Loads the dataset with pandas
# Displays column names, number of rows, data types
# Shows summary statistics (.describe())
# Checks for missing values
#
# 🛠 Tools: pandas
#
# 🎯 Goal: Understand data structure, detect missing or
# inconsistent data.

# %% [markdown]
# Step 1: importing Library

# %%
import pandas as pd

# %% [markdown]
# Step 2: Loading dataset with pandas

# %%
file_path = "/content/Car_sales.csv"
df = pd.read_csv(file_path)

# %% [markdown]
# Step 3: Displaying few rows

# %%
df.head()
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919               16.360    Passenger
# 1        Acura       TL              39.384               19.875    Passenger
# 2        Acura       CL              14.114               18.225    Passenger
# 3        Acura       RL               8.588               29.725    Passenger
# 4         Audi       A4              20.397               22.255    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0               21.50          1.8       140.0      101.2   67.3   172.4
# 1               28.40          3.2       225.0      108.1   70.3   192.9
# 2                 NaN          3.2       225.0      106.9   70.6   192.0
# 3               42.00          3.5       210.0      114.6   71.4   196.6
# 4               23.99          1.8       150.0      102.6   68.2   178.0
#
# ...

# %% [markdown]
# Step 4:
# *   Display column names
# *   Display number of rows and colmns
# *   Display data types

# %%
# Display column names
print(" Column Names:")
print(df.columns.tolist())
# Out:
#  Column Names:
# ['Manufacturer', 'Model', 'Sales_in_thousands', '__year_resale_value', 'Vehicle_type', 'Price_in_thousands', 'Engine_size', 'Horsepower', 'Wheelbase', 'Width', 'Length', 'Curb_weight', 'Fuel_capacity', 'Fuel_efficiency', 'Latest_Launch', 'Power_perf_factor']

# %%
# Display number of rows and columns
print("\n Shape of dataset (rows, columns):")
print(df.shape)
# Out:
#  Shape of dataset (rows, columns):
# (157, 16)

# %%
# Display data types
print("\n Data Types:")
print(df.dtypes)
# Out:
#  Data Types:
# Manufacturer            object
# Model                   object
# Sales_in_thousands     float64
# __year_resale_value    float64
# Vehicle_type            object
# Price_in_thousands     float64
# Engine_size            float64
# Horsepower             float64
# Wheelbase              float64
# Width                  float64
# Length                 float64
# Curb_weight            float64
# Fuel_capacity          float64
# Fuel_efficiency        float64
# Latest_Launch           object
# Power_perf_factor      float64
# dtype: object

# %% [markdown]
# Step 5: Summary Statistics

# %%
print("Summary Statistics:")
df.describe(include="all")
# Out:
# Summary Statistics:
#        Manufacturer Model  Sales_in_thousands  __year_resale_value  \
# count           157   157          157.000000           121.000000
# unique           30   156                 NaN                  NaN
# top            Ford  Neon                 NaN                  NaN
# freq             11     2                 NaN                  NaN
# mean            NaN   NaN           52.998076            18.072975
# std             NaN   NaN           68.029422            11.453384
# min             NaN   NaN            0.110000             5.160000
# 25%             NaN   NaN           14.114000            11.260000
# 50%             NaN   NaN           29.450000            14.180000
# 75%             NaN   NaN           67.956000            19.875000
# max             NaN   NaN          540.561000            67.550000
#
#        Vehicle_type  Price_in_thousands  Engine_size  Horsepower   Wheelbase  \
# ...

# %% [markdown]
# Step 6: Missing Values Check

# %%
print(df.isnull())
# Out:
#      Manufacturer  Model  Sales_in_thousands  __year_resale_value  \
# 0           False  False               False                False
# 1           False  False               False                False
# 2           False  False               False                False
# 3           False  False               False                False
# 4           False  False               False                False
# ..            ...    ...                 ...                  ...
# 152         False  False               False                 True
# 153         False  False               False                 True
# 154         False  False               False                 True
# 155         False  False               False                 True
# 156         False  False               False                 True
#
#      Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0           False               False        False       False      False
# ...

# %% [markdown]
# **Missing values per column**

# %%
print("Missing Values per Column:")
print(df.isnull().sum())
# Out:
# Missing Values per Column:
# Manufacturer            0
# Model                   0
# Sales_in_thousands      0
# __year_resale_value    36
# Vehicle_type            0
# Price_in_thousands      2
# Engine_size             1
# Horsepower              1
# Wheelbase               1
# Width                   1
# Length                  1
# Curb_weight             2
# Fuel_capacity           1
# Fuel_efficiency         3
# Latest_Launch           0
# Power_perf_factor       2
# dtype: int64
